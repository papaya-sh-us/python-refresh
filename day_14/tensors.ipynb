# %%
import torch

# Create a tensor
x = torch.tensor([1.0, 2.0, 3.0])
print(x)
# Out:
# tensor([1., 2., 3.])

# %%
a = torch.tensor([1.0, 2.0, 3.0])
b = torch.tensor([4.0, 5.0, 6.0])

print("Sum:", a + b)
print("Dot product:", torch.dot(a, b))
print("Element-wise multiply:", a * b)
print("Shape:", a.shape)
# Out:
# Sum: tensor([5., 7., 9.])
# Dot product: tensor(32.)
# Element-wise multiply: tensor([ 4., 10., 18.])
# Shape: torch.Size([3])
